# %%
# handy imports to have
# %matplotlib inline
from sympy import symbols, Eq, solve
import math
from itertools import combinations_with_replacement , permutations, combinations, count
import numpy as np
import time
import functools
from tqdm.notebook import trange, tqdm
import ipywidgets as widgets
import matplotlib.pyplot as plt
from collections import Counter, deque
import more_itertools as mit

# %%
moves = [['R', 4], ['U', 4], ['L', 3], ['D', 1], ['R', 4], ['D', 1], ['L', 5], ['R', 2]]

# %%
# puzzle input
moves = [['L', 1], ['U', 2], ['L', 1], ['U', 2], ['L', 2], ['R', 1], ['L', 1], ['U', 2], ['D', 1], ['R', 1], ['D', 2], ['L', 2], ['D', 2], ['L', 2], ['R', 1], ['U', 2], ['L', 2], ['R', 1], ['D', 1], ['R', 2], ['D', 1], ['R', 1], ['L', 2], ['U', 1], ['D', 1], ['U', 2], ['R', 1], ['L', 1], ['U', 1], ['L', 1], ['D', 2], ['L', 2], ['U', 1], ['L', 1], ['U', 1], ['D', 1], ['L', 2], ['D', 2], ['U', 1], ['R', 1], ['L', 1], ['U', 2], ['D', 1], ['U', 1], ['L', 2], ['U', 2], ['L', 2], ['R', 2], ['U', 2], ['L', 1], ['U', 2], ['R', 1], ['D', 1], ['R', 2], ['D', 1], ['R', 2], ['L', 2], ['D', 1], ['R', 1], ['D', 1], ['R', 2], ['L', 2], ['U', 1], ['D', 1], ['L', 2], ['U', 2], ['D', 1], ['L', 1], ['U', 2], ['R', 1], ['D', 2], ['R', 1], ['U', 2], ['L', 1], ['U', 1], ['L', 2], ['U', 1], ['R', 1], ['D', 2], ['L', 2], ['R', 2], ['D', 2], ['U', 1], ['L', 2], ['D', 2], ['L', 2], ['D', 2], ['L', 2], ['D', 2], ['L', 1], ['U', 1], ['L', 2], ['U', 2], ['L', 2], ['D', 1], ['U', 2], ['R', 1], ['U', 2], ['L', 1], ['U', 2], ['R', 1], ['D', 2], ['U', 2], ['D', 1], ['U', 1], ['D', 1], ['R', 1], ['U', 2], ['L', 2], ['U', 1], ['R', 2], ['U', 1], ['R', 1], ['L', 1], ['R', 3], ['L', 2], ['R', 1], ['L', 3], ['R', 2], ['D', 1], ['U', 3], ['L', 2], ['U', 3], ['R', 3], ['D', 2], ['U', 2], ['D', 2], ['L', 1], ['D', 2], ['U', 1], ['L', 3], ['U', 1], ['R', 2], ['L', 2], ['R', 3], ['D', 2], ['L', 1], ['D', 2], ['U', 1], ['L', 2], ['U', 1], ['R', 2], ['L', 1], ['U', 1], ['D', 2], ['R', 2], ['U', 2], ['D', 1], ['L', 2], ['D', 2], ['U', 3], ['L', 3], ['D', 3], ['U', 3], ['L', 3], ['R', 1], ['L', 1], ['U', 1], ['L', 3], ['D', 1], ['R', 3], ['D', 1], ['R', 2], ['L', 1], ['R', 3], ['D', 3], ['U', 1], ['R', 2], ['D', 3], ['L', 1], ['U', 1], ['D', 3], ['L', 2], ['U', 2], ['R', 1], ['U', 3], ['D', 2], ['L', 2], ['U', 1], ['L', 2], ['R', 3], ['L', 1], ['R', 1], ['U', 2], ['R', 3], ['U', 2], ['L', 1], ['U', 3], ['L', 
], ['R', 8], ['U', 4], ['R', 3], ['U', 15], ['L', 12], ['U', 10], ['L', 17], ['R', 10], ['L', 4], ['R', 13], ['D', 13], ['U', 18], ['D', 3], ['L', 4], ['R', 1], ['D', 17], ['R', 1], ['U', 19], ['L', 17], ['D', 15], ['R', 17], ['U', 10], ['D', 8], ['U', 11], ['L', 14], ['R', 9], ['L', 1], ['R', 8], ['L', 7], ['U', 8], ['R', 4], ['D', 6], ['R', 5], ['U', 17], ['D', 6], ['U', 6], ['L', 8], ['D', 5], ['L', 19], ['D', 19], ['R', 12], ['D', 3], ['U', 6], ['D', 17]]

# %%
# %%time

# part 1, 6376 is answer.


transitions = {'R':(1, 0), 'L':(-1, 0), 'U':(0,1), 'D':(0,-1)}      # how to move the head based on input
tail_moves = {-2:-1, -1:-1, 0:0, 1:1, 2:1}                          # how to move the tail based on delta with head
head = [100,100]    # my input never goes further than left 33 and down 63, so this ensures all coords are positive
tail = [100,100]    
x = 0               # x and y make my code way more readable. I was avoiding the [0] and [1] everywhere.
y = 1
tail_visited_map = set([(tail[x], tail[y])])      # set of where we've landed, length of this set will be answer

for move in moves:
    calculate_move(move)
    
print(len(tail_visited_map))
# Out:
# 6376
# CPU times: user 6.94 ms, sys: 619 µs, total: 7.56 ms
# Wall time: 7.51 ms

# %%
def calculate_move(m):
    direction, depth = m
    x_delta, y_delta = transitions[direction]
    
    for i in range(depth):
        # move the head
        head[x] += x_delta
        head[y] += y_delta
        
        # see how far away tail is from head
        x_diff = head[x] - tail[x]
        y_diff = head[y] - tail[y]
        
        # if needed, move the tail to reduce distance
        if abs(x_diff) > 1 or abs(y_diff) > 1:
            tail[x] += tail_moves[x_diff]
            tail[y] += tail_moves[y_diff]
            tail_visited_map.update([(tail[x],tail[y])])

# %%
# part 2: 10 knots, 2607 is answer

# %%
# %%time
transitions = {'R':(1, 0), 'L':(-1, 0), 'U':(0,1), 'D':(0,-1)}
tail_moves = {-2:-1, -1:-1, 0:0, 1:1, 2:1}
rope = [[100,100], [100,100], [100,100], [100,100], [100,100], [100,100], [100,100], [100,100], [100,100], [100,100]]    
tail = rope[9]
x = 0
y = 1
tail_visited_map = set([(tail[x], tail[y])])

for move in moves:
    # decode the move
    direction, depth = move
    x_delta, y_delta = transitions[direction]
    

    for i in range(depth):      # for all the steps in this move
        # move the head
        rope[0][x] += x_delta
        rope[0][y] += y_delta
        for j in range(0, len(rope)-1):   # if needed move the rest of the knots
            calculate_multi_move(j, j+1)
        tail_visited_map.update([(tail[x],tail[y])])  # after all moves done, 
    
print(len(tail_visited_map))
# Out:
# 2607
# CPU times: user 46.3 ms, sys: 1.61 ms, total: 47.9 ms
# Wall time: 47.4 ms

# %%
def calculate_multi_move(a, b):
    # if needed, move the tail
        x_diff = rope[a][x] - rope[b][x]
        y_diff = rope[a][y] - rope[b][y]
        
        if abs(x_diff) > 1 or abs(y_diff) > 1:
            rope[b][x] += tail_moves[x_diff]
            rope[b][y] += tail_moves[y_diff]

# %%
tail
# Out:
# [105, 100]

# %%
# Out:
# [105, 100]
