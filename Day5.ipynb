# %%
# %matplotlib inline
from sympy import symbols, Eq, solve
import math
from itertools import combinations_with_replacement , permutations, combinations
import numpy as np
import time
import functools
from tqdm.notebook import trange, tqdm
import ipywidgets as widgets
import matplotlib.pyplot as plt

# %%
stacksIn = [[ [''],['D'],['']],
            [['N'],['C'],['']],
            [['Z'],['M'],['P']]]

moves = [[1,2,1], [3,1,3], [2,2,1], [1,1,2]]

# %%
# I feel like the nested arrays of characters is a bit more complex than it should be
# but was the easiest form to put it in given the input format and that I did this in  
# Sublime with multi-line cursors.
# also prints out nicely below.

stacksIn = [[['C'], ['' ], ['' ], ['S'], ['H'], ['' ], ['' ], ['' ], ['' ]], 
            [['F'] ,['B'], ['' ], ['C'], ['S'], ['' ], ['W'], ['' ], ['' ]], 
            [['B'] ,['W'], ['' ], ['W'], ['M'], ['S'], ['B'], ['' ], ['' ]], 
            [['L'] ,['H'], ['G'], ['L'], ['P'], ['F'], ['Q'], ['' ], ['' ]], 
            [['D'] ,['P'], ['J'], ['F'], ['T'], ['G'], ['M'], ['T'], ['' ]], 
            [['P'] ,['G'], ['B'], ['N'], ['L'], ['W'], ['P'], ['W'], ['R']], 
            [['Z'] ,['V'], ['W'], ['J'], ['J'], ['C'], ['T'], ['S'], ['C']], 
            [['S'] ,['N'], ['F'], ['G'], ['W'], ['B'], ['H'], ['F'], ['N']]]

moves = [[2, 5, 9], [3, 1, 7], [2, 3, 9], [6, 9, 5], [2, 3, 8], [9, 7, 8], [15, 8, 9], [3, 1, 6], [6, 4, 2], [6, 5, 6], [1, 4, 2], [14, 6, 2], [2, 1, 5], [1, 7, 3], [1, 4, 8], [2, 5, 6], [25, 2, 4], [2, 6, 4], [1, 8, 1], [2, 9, 1], [1, 6, 1], [2, 1, 7], [1, 7, 3], [2, 1, 8], [1, 2, 6], [1, 3, 8], [4, 5, 6], [1, 5, 3], [1, 9, 6], [2, 3, 4], [1, 2, 6], [12, 9, 7], [1, 9, 1], [1, 5, 8], [1, 3, 8], [28, 4, 5], [1, 4, 3], [1, 2, 6], [1, 3, 9], [12, 7, 2], [1, 9, 6], [6, 6, 4], [1, 7, 4], [1, 1, 2], [28, 5, 1], [2, 2, 8], [3, 8, 2], [7, 4, 1], [4, 8, 6], [9, 2, 8], [7, 6, 5], [3, 5, 9], [1, 9, 7], [1, 7, 1], [5, 8, 4], [4, 1, 9], [6, 9, 4], [5, 1, 5], [5, 2, 3], [4, 8, 2], [5, 1, 4], [4, 5, 9], [9, 4, 9], [10, 9, 8], [1, 9, 1], [2, 2, 8], [4, 3, 8], [1, 2, 3], [2, 9, 2], [1, 2, 6], [4, 4, 3], [3, 5, 1], [12, 1, 4], [1, 5, 3], [1, 5, 3], [5, 8, 5], [7, 8, 5], [8, 3, 4], [1, 5, 1], [1, 6, 7], [2, 1, 6], [8, 5, 9], [2, 5, 1], [9, 1, 4], [20, 4, 2], [1, 5, 2], [4, 4, 2], [5, 9
[9, 6, 9], [2, 2, 9], [1, 5, 1], [5, 9, 7], [8, 2, 5], [1, 1, 9], [3, 9, 1], [5, 3, 6], [8, 5, 9], [13, 3, 9], [3, 1, 7], [5, 7, 9], [17, 9, 6], [1, 7, 6], [6, 3, 9], [1, 2, 1], [2, 7, 1], [1, 2, 5], [21, 9, 2], [4, 3, 6], [6, 6, 5], [7, 5, 9], [2, 3, 8], [3, 1, 3], [4, 6, 5], [1, 8, 1], [1, 8, 2], [4, 5, 2], [4, 9, 1], [4, 3, 5], [2, 1, 7], [1, 7, 4], [3, 9, 5], [25, 2, 9], [18, 9, 1], [1, 4, 5], [1, 3, 8], [4, 5, 6], [2, 9, 3], [17, 1, 5], [1, 2, 7], [2, 3, 5], [3, 1, 8], [5, 9, 2], [4, 8, 9], [12, 5, 2], [1, 1, 8], [3, 9, 5], [1, 8, 2], [2, 7, 2], [1, 9, 5], [9, 5, 2], [6, 6, 2], [15, 6, 2], [5, 5, 9], [1, 5, 9], [3, 9, 2], [3, 9, 1], [1, 1, 9], [1, 9, 1], [19, 2, 8], [2, 1, 9], [33, 2, 6], [4, 6, 4], [1, 2, 6], [1, 9, 8], [3, 4, 8], [18, 8, 3], [1, 4, 9], [10, 3, 9], [1, 1, 4], [24, 6, 3], [1, 4, 3], [2, 8, 7], [8, 9, 3], [5, 6, 7], [35, 3, 2], [7, 7, 1], [3, 1, 3], [33, 2, 6], [6, 3, 7], [5, 7, 3], [1, 1, 4], [1, 7, 8], [1, 4, 8], [1, 3, 2], [30, 6, 5], [2, 1, 6], [5, 8, 1], [1, 9, 2], [2, 6, 4], [4, 1, 7], [21, 5, 8]]

# %%
# code for part 1 (and 2, code was only 5 chars different)

stacks = [[] for i in range(0, len(stacksIn)+2)]
for line in stacksIn[::-1]:
    for i, crate in enumerate(line):
        #print(crate, type(crate))
        stacks[i+1] += crate[0]
    
for i, s in enumerate(stacks):
    print(i,s)

for move in moves:
    qty, start, end = move
    moveChain = stacks[start][-qty:]
    stacks[start] = stacks[start][:-qty]
    #stacks[end] = stacks[end] + moveChain[::-1]      # part one ansser
    stacks[end] = stacks[end] + moveChain             # part two answer

    
#print (stacks)

ans = ''
for s in stacks:
    if s:                     # empty lists are considered false in python
        ans += s[-1][0]
        
print('a:', ans)
# Out:
# 0 []
# 1 ['S', 'Z', 'P', 'D', 'L', 'B', 'F', 'C']
# 2 ['N', 'V', 'G', 'P', 'H', 'W', 'B']
# 3 ['F', 'W', 'B', 'J', 'G']
# 4 ['G', 'J', 'N', 'F', 'L', 'W', 'C', 'S']
# 5 ['W', 'J', 'L', 'T', 'P', 'M', 'S', 'H']
# 6 ['B', 'C', 'W', 'G', 'F', 'S']
# 7 ['H', 'T', 'P', 'M', 'Q', 'B', 'W']
# 8 ['F', 'S', 'W', 'T']
# 9 ['N', 'C', 'R']
# a: PWPWHGFZS
